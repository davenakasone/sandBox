# %%
import pandas as pd
# html is dirty, you should clean it very good (try using the API if there is one)
# excel is something you should not fight, most people can only use excel

# %%
html_url = 'https://www.basketball-reference.com/leagues/NBA_2019.html'
nba = pd.read_html(html_url)
len(nba)
# Out:
# 13

# %%
nba[0].head()
# Out:
#     Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0     Milwaukee Bucks*  60  22  0.732     —  118.1  109.3  8.04
# 1     Toronto Raptors*  58  24  0.707   2.0  114.4  108.4  5.49
# 2  Philadelphia 76ers*  51  31  0.622   9.0  115.2  112.5  2.25
# 3      Boston Celtics*  49  33  0.598  11.0  112.4  108.0  3.90
# 4      Indiana Pacers*  48  34  0.585  12.0  108.0  104.7  2.76

# %%
sp = pd.read_html('https://en.wikipedia.org/wiki/South_Park')
len(sp)
sp[3].head()
# Out:
#         0                                                  1
# 0    Kids  Stan Marsh Kyle Broflovski Eric Cartman Kenny ...
# 1  Adults  Randy and Sharon Marsh Gerald and Sheila Brofl...
# 2   Lists  Families Children School staff Other recurring...

# %%
# the read_excel method
df = pd.read_excel('movies.xls', sheet_name='2000s')
df.head()
# Out:
#                     Title  Year                   Genres Language Country  \
# 0         102 Dalmatians   2000  Adventure|Comedy|Family  English     USA
# 1                28 Days   2000             Comedy|Drama  English     USA
# 2              3 Strikes   2000                   Comedy  English     USA
# 3               Aberdeen   2000                    Drama  English      UK
# 4  All the Pretty Horses   2000    Drama|Romance|Western  English     USA
#
#   Content Rating  Duration  Aspect Ratio      Budget  Gross Earnings  ...  \
# 0              G     100.0          1.85  85000000.0      66941559.0  ...
# 1          PG-13     103.0          1.37  43000000.0      37035515.0  ...
# 2              R      82.0          1.85   6000000.0       9821335.0  ...
# 3            NaN     106.0          1.85   6500000.0         64148.0  ...
# 4          PG-13     220.0          2.35  57000000.0      15527125.0  ...
#
# ...

# %%
# ExcelFile class
ef = pd.ExcelFile('movies.xls')
ef.sheet_names
# Out:
# ['1900s', '2000s', '2010s']

# %%
y90 = ef.parse(ef.sheet_names[0])
y90.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# ...

# %%
y90.dtypes
# Out:
# Title                           object
# Year                             int64
# Genres                          object
# Language                        object
# Country                         object
# Content Rating                  object
# Duration                         int64
# Aspect Ratio                   float64
# Budget                         float64
# Gross Earnings                 float64
# Director                        object
# Actor 1                         object
# Actor 2                         object
# Actor 3                         object
# Facebook Likes - Director        int64
# Facebook Likes - Actor 1         int64
# Facebook Likes - Actor 2         int64
# Facebook Likes - Actor 3       float64
# Facebook Likes - cast Total      int64
# Facebook likes - Movie           int64
# Facenumber in posters            int64
# User Votes                       int64
# Reviews by Users                 int64
# Reviews by Crtiics             float64
# ...

# %%
# save processed data
y90.to_excel('out.xlsx', index=None)
pd.read_excel('out.xlsx').head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# ...
