# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([1,2,3,4],dtype=np.int16)

# %%
print(a)
# Out:
# [1 2 3 4]

# %%
plt.plot(a,a)
plt.title("x vs y")
plt.ylabel("y-axis")
plt.xlabel("x-axis")
plt.show()
